# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import functools

# Creates a tf feature spec from the dataframe and columns specified.
def create_feature_spec(df, columns=None):
    feature_spec = {}
    if columns == None:
        columns = df.columns.values.tolist()
    for f in columns:
        if df[f].dtype is np.dtype(np.int64):
            feature_spec[f] = tf.FixedLenFeature(shape=(), dtype=tf.int64)
        elif df[f].dtype is np.dtype(np.float64):
            feature_spec[f] = tf.FixedLenFeature(shape=(), dtype=tf.float32)
        else:
            feature_spec[f] = tf.FixedLenFeature(shape=(), dtype=tf.string)
    return feature_spec

# Creates simple numeric and categorical feature columns from a feature spec and a
# list of columns from that spec to use.
#
# NOTE: Models might perform better with some feature engineering such as bucketed
# numeric columns and hash-bucket/embedding columns for categorical features.
def create_feature_columns(columns, feature_spec):
    ret = []
    for col in columns:
        if feature_spec[col].dtype is tf.int64 or feature_spec[col].dtype is tf.float32:
            ret.append(tf.feature_column.numeric_column(col))
        else:
            ret.append(tf.feature_column.indicator_column(
                tf.feature_column.categorical_column_with_vocabulary_list(col, list(df[col].unique()))))
    return ret

# An input function for providing input to a model from tf.Examples
def tfexamples_input_fn(examples, feature_spec, label, mode=tf.estimator.ModeKeys.EVAL,
                       num_epochs=None, 
                       batch_size=64):
    def ex_generator():
        for i in range(len(examples)):
            yield examples[i].SerializeToString()
    dataset = tf.data.Dataset.from_generator(
      ex_generator, tf.dtypes.string, tf.TensorShape([]))
    if mode == tf.estimator.ModeKeys.TRAIN:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda tf_example: parse_tf_example(tf_example, label, feature_spec))
    dataset = dataset.repeat(num_epochs)
    return dataset

# Parses Tf.Example protos into features for the input function.
def parse_tf_example(example_proto, label, feature_spec):
    parsed_features = tf.parse_example(serialized=example_proto, features=feature_spec)
    target = parsed_features.pop(label)
    return parsed_features, target

# Converts a dataframe into a list of tf.Example protos.
def df_to_examples(df, columns=None):
    examples = []
    if columns == None:
        columns = df.columns.values.tolist()
    for index, row in df.iterrows():
        example = tf.train.Example()
        for col in columns:
            if df[col].dtype is np.dtype(np.int64):
                example.features.feature[col].int64_list.value.append(int(row[col]))
            elif df[col].dtype is np.dtype(np.float64):
                example.features.feature[col].float_list.value.append(row[col])
            elif row[col] == row[col]:
                example.features.feature[col].bytes_list.value.append(row[col].encode('utf-8'))
        examples.append(example)
    return examples

# Converts a dataframe column into a column of 0's and 1's based on the provided test.
# Used to force label columns to be numeric for binary classification using a TF estimator.
def make_label_column_numeric(df, label_column, test):
  df[label_column] = np.where(test(df[label_column]), 1, 0)

# %%
import pandas as pd

df = pd.read_csv('https://storage.googleapis.com/what-if-tool-resources/computefest2019/cox-violent-parsed_filt.csv')
df
# Out:
#          id                   name        first         last     sex  \
# 0       1.0       miguel hernandez       miguel    hernandez    Male
# 1       2.0       miguel hernandez       miguel    hernandez    Male
# 2       3.0           michael ryan      michael         ryan    Male
# 3       4.0            kevon dixon        kevon        dixon    Male
# 4       5.0               ed philo           ed        philo    Male
# 5       6.0               ed philo           ed        philo    Male
# 6       7.0               ed philo           ed        philo    Male
# 7       8.0               ed philo           ed        philo    Male
# 8       9.0               ed philo           ed        philo    Male
# 9      10.0            marcu brown        marcu        brown    Male
# 10     11.0     bouthy pierrelouis       bouthy  pierrelouis    Male
# 11     12.0           marsha miles       marsha        miles    Male
# 12     13.0          edward riddle       edward       riddle    Male
# 13     14.0          edward riddle       edward       riddle    Male
# 14     15.0         steven stewart       steven      stewart    Male
# 15     16.0         steven stewart       steven      stewart    Male
# 16     17.0         steven stewart       steven      stewart    Male
# 17     18.0       elizabeth thieme    elizabeth       thieme  Female
# 18     19.0      darrell blackburn      darrell    blackburn    Male
# 19     20.0      darrell blackburn      darrell    blackburn    Male
# 20     21.0      darrell blackburn      darrell    blackburn    Male
# 21     22.0             jamie good        jamie         good  Female
# 22     23.0             jamie good        jamie         good  Female
# 23     24.0             jamie good        jamie         good  Female
# 24     25.0              bo bradac           bo       bradac    Male
# 25     26.0         benjamin franc     benjamin        franc    Male
# 26     27.0         ellyaher lanza     ellyaher        lanza    Male
# 27     28.0        kortney coleman      kortney      coleman  Female
# 28     29.0             kyle lewis         kyle        lewis    Male
# 29     30.0           jarrod turbe       jarrod        turbe    Male
# ...     ...                    ...          ...          ...     ...
# 18286   NaN       shantrina stfort    shantrina       stfort  Female
# 18287   NaN            kyle miller         kyle       miller    Male
# 18288   NaN            kyle miller         kyle       miller    Male
# 18289   NaN            kyle miller         kyle       miller    Male
# 18290   NaN            kyle miller         kyle       miller    Male
# 18291   NaN            kyle miller         kyle       miller    Male
# 18292   NaN            kyle miller         kyle       miller    Male
# 18293   NaN        michelle greigg     michelle       greigg  Female
# 18294   NaN           ceasar gomez       ceasar        gomez    Male
# 18295   NaN           ceasar gomez       ceasar        gomez    Male
# 18296   NaN         luis fernandez         luis    fernandez    Male
# 18297   NaN      rodney montgomery       rodney   montgomery    Male
# 18298   NaN        christopher tun  christopher          tun    Male
# 18299   NaN        christopher tun  christopher          tun    Male
# 18300   NaN        christopher tun  christopher          tun    Male
# 18301   NaN         kevin mcdonald        kevin     mcdonald    Male
# 18302   NaN         alexander vega    alexander         vega    Male
# 18303   NaN      natalia rodriguez      natalia    rodriguez  Female
# 18304   NaN           jarred payne       jarred        payne    Male
# 18305   NaN           jarred payne       jarred        payne    Male
# 18306   NaN           raheem smith       raheem        smith    Male
# 18307   NaN           raheem smith       raheem        smith    Male
# 18308   NaN           raheem smith       raheem        smith    Male
# 18309   NaN          steven butler       steven       butler    Male
# 18310   NaN        malcolm simmons      malcolm      simmons    Male
# 18311   NaN  alexsandra beauchamps   alexsandra   beauchamps  Female
# 18312   NaN        winston gregory      winston      gregory    Male
# 18313   NaN            farrah jean       farrah         jean  Female
# 18314   NaN    florencia sanmartin    florencia    sanmartin  Female
# 18315   NaN    florencia sanmartin    florencia    sanmartin  Female
#
#               dob  age          age_cat              race  juv_fel_count  ...  \
# 0      18/04/1947   69  Greater than 45             Other              0  ...
# 1      18/04/1947   69  Greater than 45             Other              0  ...
# 2      06/02/1985   31          25 - 45         Caucasian              0  ...
# 3      22/01/1982   34          25 - 45  African-American              0  ...
# 4      14/05/1991   24     Less than 25  African-American              0  ...
# 5      14/05/1991   24     Less than 25  African-American              0  ...
# 6      14/05/1991   24     Less than 25  African-American              0  ...
# 7      14/05/1991   24     Less than 25  African-American              0  ...
# 8      14/05/1991   24     Less than 25  African-American              0  ...
# 9      21/01/1993   23     Less than 25  African-American              0  ...
# 10     22/01/1973   43          25 - 45             Other              0  ...
# 11     22/08/1971   44          25 - 45             Other              0  ...
# 12     23/07/1974   41          25 - 45         Caucasian              0  ...
# 13     23/07/1974   41          25 - 45         Caucasian              0  ...
# 14     25/02/1973   43          25 - 45             Other              0  ...
# 15     25/02/1973   43          25 - 45             Other              0  ...
# 16     25/02/1973   43          25 - 45             Other              0  ...
# 17     03/06/1976   39          25 - 45         Caucasian              0  ...
# 18     16/11/1995   20     Less than 25         Caucasian              0  ...
# 19     16/11/1995   20     Less than 25         Caucasian              0  ...
# 20     16/11/1995   20     Less than 25         Caucasian              0  ...
# 21     23/04/1989   26          25 - 45         Caucasian              0  ...
# 22     23/04/1989   26          25 - 45         Caucasian              0  ...
# 23     23/04/1989   26          25 - 45         Caucasian              0  ...
# 24     10/06/1994   21     Less than 25         Caucasian              0  ...
# 25     01/06/1988   27          25 - 45         Caucasian              0  ...
# 26     18/08/1992   23     Less than 25  African-American              0  ...
# 27     22/08/1978   37          25 - 45         Caucasian              0  ...
# 28     18/04/1994   22     Less than 25         Caucasian              0  ...
# 29     02/12/1974   41          25 - 45  African-American              0  ...
# ...           ...  ...              ...               ...            ...  ...
# 18286  06/06/1995   20     Less than 25  African-American              0  ...
# 18287  08/04/1986   30          25 - 45  African-American              0  ...
# 18288  08/04/1986   30          25 - 45  African-American              0  ...
# 18289  08/04/1986   30          25 - 45  African-American              0  ...
# 18290  08/04/1986   30          25 - 45  African-American              0  ...
# 18291  08/04/1986   30          25 - 45  African-American              0  ...
# 18292  08/04/1986   30          25 - 45  African-American              0  ...
# 18293  06/10/1972   43          25 - 45  African-American              0  ...
# 18294  07/02/1990   26          25 - 45          Hispanic              0  ...
# 18295  07/02/1990   26          25 - 45          Hispanic              0  ...
# 18296  19/09/1971   44          25 - 45          Hispanic              0  ...
# 18297  28/09/1985   30          25 - 45  African-American              0  ...
# 18298  28/04/1992   23     Less than 25         Caucasian              0  ...
# 18299  28/04/1992   23     Less than 25         Caucasian              0  ...
# 18300  28/04/1992   23     Less than 25         Caucasian              0  ...
# 18301  21/12/1985   30          25 - 45         Caucasian              0  ...
# 18302  15/07/1994   21     Less than 25         Caucasian              0  ...
# 18303  28/07/1981   34          25 - 45         Caucasian              0  ...
# 18304  31/07/1985   30          25 - 45  African-American              0  ...
# 18305  31/07/1985   30          25 - 45  African-American              0  ...
# 18306  28/06/1995   20     Less than 25  African-American              0  ...
# 18307  28/06/1995   20     Less than 25  African-American              0  ...
# 18308  28/06/1995   20     Less than 25  African-American              0  ...
# 18309  17/07/1992   23     Less than 25  African-American              0  ...
# 18310  25/03/1993   23     Less than 25  African-American              0  ...
# 18311  21/12/1984   31          25 - 45  African-American              0  ...
# 18312  01/10/1958   57  Greater than 45             Other              0  ...
# 18313  17/11/1982   33          25 - 45  African-American              0  ...
# 18314  18/12/1992   23     Less than 25          Hispanic              0  ...
# 18315  18/12/1992   23     Less than 25          Hispanic              0  ...
#
#                        vr_charge_desc  type_of_assessment  decile_score.1  \
# 0                                 NaN  Risk of Recidivism               1
# 1                                 NaN  Risk of Recidivism               1
# 2                                 NaN  Risk of Recidivism               5
# 3         Felony Battery (Dom Strang)  Risk of Recidivism               3
# 4                                 NaN  Risk of Recidivism               4
# 5                                 NaN  Risk of Recidivism               4
# 6                                 NaN  Risk of Recidivism               4
# 7                                 NaN  Risk of Recidivism               4
# 8                                 NaN  Risk of Recidivism               4
# 9                                 NaN  Risk of Recidivism               8
# 10                                NaN  Risk of Recidivism               1
# 11                                NaN  Risk of Recidivism               1
# 12                                NaN  Risk of Recidivism               6
# 13                                NaN  Risk of Recidivism               6
# 14                                NaN  Risk of Recidivism               4
# 15                                NaN  Risk of Recidivism               4
# 16                                NaN  Risk of Recidivism               4
# 17                                NaN  Risk of Recidivism               1
# 18                                NaN  Risk of Recidivism              10
# 19                                NaN  Risk of Recidivism              10
# 20                                NaN  Risk of Recidivism              10
# 21                                NaN  Risk of Recidivism               5
# 22                                NaN  Risk of Recidivism               5
# 23                                NaN  Risk of Recidivism               5
# 24     Aggrav Battery w/Deadly Weapon  Risk of Recidivism               3
# 25                                NaN  Risk of Recidivism               4
# 26                                NaN  Risk of Recidivism               6
# 27                                NaN  Risk of Recidivism               1
# 28                                NaN  Risk of Recidivism               3
# 29                                NaN  Risk of Recidivism               4
# ...                               ...                 ...             ...
# 18286                             NaN  Risk of Recidivism               7
# 18287                             NaN  Risk of Recidivism              10
# 18288                             NaN  Risk of Recidivism              10
# 18289                             NaN  Risk of Recidivism              10
# 18290                             NaN  Risk of Recidivism              10
# 18291                             NaN  Risk of Recidivism              10
# 18292                             NaN  Risk of Recidivism              10
# 18293                             NaN  Risk of Recidivism               1
# 18294                             NaN  Risk of Recidivism               2
# 18295                             NaN  Risk of Recidivism               2
# 18296                             NaN  Risk of Recidivism               3
# 18297                             NaN  Risk of Recidivism               4
# 18298                         Assault  Risk of Recidivism              10
# 18299                         Assault  Risk of Recidivism              10
# 18300                         Assault  Risk of Recidivism              10
# 18301                             NaN  Risk of Recidivism               2
# 18302                             NaN  Risk of Recidivism               6
# 18303                             NaN  Risk of Recidivism               7
# 18304                             NaN  Risk of Recidivism               2
# 18305                             NaN  Risk of Recidivism               2
# 18306                             NaN  Risk of Recidivism               9
# 18307                             NaN  Risk of Recidivism               9
# 18308                             NaN  Risk of Recidivism               9
# 18309                             NaN  Risk of Recidivism               7
# 18310                             NaN  Risk of Recidivism               3
# 18311                             NaN  Risk of Recidivism               6
# 18312                             NaN  Risk of Recidivism               1
# 18313                             NaN  Risk of Recidivism               2
# 18314                             NaN  Risk of Recidivism               4
# 18315                             NaN  Risk of Recidivism               4
#
#        score_text  screening_date v_type_of_assessment v_decile_score  \
# 0             Low      14/08/2013     Risk of Violence              1
# 1             Low      14/08/2013     Risk of Violence              1
# 2          Medium      31/12/2014     Risk of Violence              2
# 3             Low      27/01/2013     Risk of Violence              1
# 4             Low      14/04/2013     Risk of Violence              3
# 5             Low      14/04/2013     Risk of Violence              3
# 6             Low      14/04/2013     Risk of Violence              3
# 7             Low      14/04/2013     Risk of Violence              3
# 8             Low      14/04/2013     Risk of Violence              3
# 9            High      13/01/2013     Risk of Violence              6
# 10            Low      26/03/2013     Risk of Violence              1
# 11            Low      30/11/2013     Risk of Violence              1
# 12         Medium      19/02/2014     Risk of Violence              2
# 13         Medium      19/02/2014     Risk of Violence              2
# 14            Low      30/08/2013     Risk of Violence              3
# 15            Low      30/08/2013     Risk of Violence              3
# 16            Low      30/08/2013     Risk of Violence              3
# 17            Low      16/03/2014     Risk of Violence              1
# 18           High      09/12/2013     Risk of Violence              9
# 19           High      09/12/2013     Risk of Violence              9
# 20           High      09/12/2013     Risk of Violence              9
# 21         Medium      05/09/2014     Risk of Violence              3
# 22         Medium      05/09/2014     Risk of Violence              3
# 23         Medium      05/09/2014     Risk of Violence              3
# 24            Low      04/11/2013     Risk of Violence              5
# 25            Low      26/11/2013     Risk of Violence              4
# 26         Medium      03/10/2013     Risk of Violence              4
# 27            Low      01/01/2013     Risk of Violence              1
# 28            Low      31/07/2014     Risk of Violence              5
# 29            Low      09/10/2013     Risk of Violence              2
# ...           ...             ...                  ...            ...
# 18286      Medium      05/11/2013     Risk of Violence              7
# 18287        High      22/01/2014     Risk of Violence              7
# 18288        High      22/01/2014     Risk of Violence              7
# 18289        High      22/01/2014     Risk of Violence              7
# 18290        High      22/01/2014     Risk of Violence              7
# 18291        High      22/01/2014     Risk of Violence              7
# 18292        High      22/01/2014     Risk of Violence              7
# 18293         Low      16/11/2014     Risk of Violence              1
# 18294         Low      31/03/2013     Risk of Violence              3
# 18295         Low      31/03/2013     Risk of Violence              3
# 18296         Low      27/10/2013     Risk of Violence              1
# 18297         Low      28/12/2013     Risk of Violence              3
# 18298        High      28/05/2013     Risk of Violence              9
# 18299        High      28/05/2013     Risk of Violence              9
# 18300        High      28/05/2013     Risk of Violence              9
# 18301         Low      25/06/2014     Risk of Violence              2
# 18302      Medium      10/05/2013     Risk of Violence              7
# 18303      Medium      14/11/2014     Risk of Violence              3
# 18304         Low      10/05/2014     Risk of Violence              2
# 18305         Low      10/05/2014     Risk of Violence              2
# 18306        High      20/10/2013     Risk of Violence              9
# 18307        High      20/10/2013     Risk of Violence              9
# 18308        High      20/10/2013     Risk of Violence              9
# 18309      Medium      23/11/2013     Risk of Violence              5
# 18310         Low      01/02/2014     Risk of Violence              5
# 18311      Medium      29/12/2014     Risk of Violence              4
# 18312         Low      14/01/2014     Risk of Violence              1
# 18313         Low      09/03/2014     Risk of Violence              2
# 18314         Low      30/06/2014     Risk of Violence              4
# 18315         Low      30/06/2014     Risk of Violence              4
#
#        v_score_text priors_count.1 event
# 0               Low              0     0
# 1               Low              0     0
# 2               Low              0     0
# 3               Low              0     1
# 4               Low              4     0
# 5               Low              4     0
# 6               Low              4     0
# 7               Low              4     0
# 8               Low              4     0
# 9            Medium              1     0
# 10              Low              2     0
# 11              Low              0     0
# 12              Low             14     0
# 13              Low             14     0
# 14              Low              3     0
# 15              Low              3     0
# 16              Low              3     0
# 17              Low              0     0
# 18             High              0     0
# 19             High              0     0
# 20             High              0     0
# 21              Low              0     0
# 22              Low              0     0
# 23              Low              0     0
# 24           Medium              1     1
# 25              Low              0     0
# 26              Low              3     0
# 27              Low              0     0
# 28           Medium              0     0
# 29              Low              0     0
# ...             ...            ...   ...
# 18286        Medium              0     0
# 18287        Medium             19     0
# 18288        Medium             19     0
# 18289        Medium             19     0
# 18290        Medium             19     0
# 18291        Medium             19     0
# 18292        Medium             19     0
# 18293           Low              0     0
# 18294           Low              0     0
# 18295           Low              0     0
# 18296           Low              0     0
# 18297           Low              2     0
# 18298          High              5     0
# 18299          High              5     0
# 18300          High              5     1
# 18301           Low              1     0
# 18302        Medium              0     0
# 18303           Low              7     0
# 18304           Low              0     0
# 18305           Low              0     0
# 18306          High              0     0
# 18307          High              0     0
# 18308          High              0     0
# 18309        Medium              0     0
# 18310        Medium              0     0
# 18311           Low              5     0
# 18312           Low              0     0
# 18313           Low              3     0
# 18314           Low              2     0
# 18315           Low              2     0
#
# [18316 rows x 40 columns]

# %%
#@title Specify input columns and column to predict {display-mode: "form"}
import numpy as np

# Filter out entries with no indication of recidivism or no compass score
df = df[df['is_recid'] != -1]
df = df[df['decile_score'] != -1]

# Rename recidivism column
df['recidivism_within_2_years'] = df['is_recid']

# Make the COMPASS label column numeric (0 and 1), for use in our model
df['COMPASS_determination'] = np.where(df['score_text'] == 'Low', 0, 1)

# Set column to predict
label_column = 'COMPASS_determination'

# Get list of all columns from the dataset we will use for model input or output.
input_features = ['sex', 'age', 'race', 'priors_count', 'juv_fel_count', 'juv_misd_count', 'juv_other_count']
features_and_labels = input_features + [label_column]

features_for_file = input_features + ['recidivism_within_2_years', 'COMPASS_determination']

# %%
examples = df_to_examples(df, features_for_file)

# %%
num_steps = 2000  #@param {type: "number"}
tf.logging.set_verbosity(tf.logging.DEBUG)

# Create a feature spec for the classifier
feature_spec = create_feature_spec(df, features_and_labels)

# Define and train the classifier
train_inpf = functools.partial(tfexamples_input_fn, examples, feature_spec, label_column)
classifier = tf.estimator.LinearClassifier(
    feature_columns=create_feature_columns(input_features, feature_spec))
classifier.train(train_inpf, steps=num_steps)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp5eueu48r
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_service': None, '_train_distribute': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_protocol': None, '_is_chief': True, '_save_summary_steps': 100, '_task_type': 'worker', '_global_id_in_cluster': 0, '_num_ps_replicas': 0, '_keep_checkpoint_every_n_hours': 10000, '_task_id': 0, '_master': '', '_device_fn': None, '_log_step_count_steps': 100, '_num_worker_replicas': 1, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff95f21ada0>, '_save_checkpoints_secs': 600, '_evaluation_master': '', '_save_checkpoints_steps': None, '_experimental_distribute': None, '_eval_distribute': None, '_model_dir': '/tmp/tmp5eueu48r'}
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/data/ops/dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# INFO:tensorflow:Calling model_fn.
# DEBUG:tensorflow:Transforming feature_column NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None).
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# DEBUG:tensorflow:Transforming feature_column NumericColumn(key='juv_fel_count', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None).
# DEBUG:tensorflow:Transforming feature_column NumericColumn(key='juv_misd_count', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None).
# DEBUG:tensorflow:Transforming feature_column NumericColumn(key='juv_other_count', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None).
# DEBUG:tensorflow:Transforming feature_column NumericColumn(key='priors_count', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None).
# DEBUG:tensorflow:Transforming feature_column IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='race', vocabulary_list=('Other', 'African-American', 'Caucasian', 'Hispanic', 'Asian', 'Native American'), dtype=tf.string, default_value=-1, num_oov_buckets=0)).
# DEBUG:tensorflow:Transforming feature_column VocabularyListCategoricalColumn(key='race', vocabulary_list=('Other', 'African-American', 'Caucasian', 'Hispanic', 'Asian', 'Native American'), dtype=tf.string, default_value=-1, num_oov_buckets=0).
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/lookup_ops.py:1137: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:4266: IndicatorColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:4321: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# DEBUG:tensorflow:Transforming feature_column IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='sex', vocabulary_list=('Male', 'Female'), dtype=tf.string, default_value=-1, num_oov_buckets=0)).
# DEBUG:tensorflow:Transforming feature_column VocabularyListCategoricalColumn(key='sex', vocabulary_list=('Male', 'Female'), dtype=tf.string, default_value=-1, num_oov_buckets=0).
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp5eueu48r/model.ckpt.
# INFO:tensorflow:loss = 44.36142, step = 1
# INFO:tensorflow:global_step/sec: 163.317
# INFO:tensorflow:loss = 44.609535, step = 101 (0.613 sec)
# INFO:tensorflow:global_step/sec: 174.938
# INFO:tensorflow:loss = 38.873524, step = 201 (0.572 sec)
# INFO:tensorflow:global_step/sec: 177.896
# INFO:tensorflow:loss = 32.310104, step = 301 (0.562 sec)
# INFO:tensorflow:global_step/sec: 182.601
# INFO:tensorflow:loss = 29.054468, step = 401 (0.548 sec)
# INFO:tensorflow:global_step/sec: 173.486
# INFO:tensorflow:loss = 35.409317, step = 501 (0.576 sec)
# INFO:tensorflow:global_step/sec: 194.523
# INFO:tensorflow:loss = 30.013563, step = 601 (0.514 sec)
# INFO:tensorflow:global_step/sec: 190.448
# INFO:tensorflow:loss = 35.648113, step = 701 (0.525 sec)
# INFO:tensorflow:global_step/sec: 152.345
# INFO:tensorflow:loss = 38.681755, step = 801 (0.657 sec)
# INFO:tensorflow:global_step/sec: 196.233
# INFO:tensorflow:loss = 25.567307, step = 901 (0.509 sec)
# INFO:tensorflow:global_step/sec: 177.609
# INFO:tensorflow:loss = 30.044853, step = 1001 (0.563 sec)
# INFO:tensorflow:global_step/sec: 187.054
# INFO:tensorflow:loss = 31.570982, step = 1101 (0.535 sec)
# INFO:tensorflow:global_step/sec: 199.306
# INFO:tensorflow:loss = 26.799519, step = 1201 (0.502 sec)
# INFO:tensorflow:global_step/sec: 195.32
# INFO:tensorflow:loss = 34.771217, step = 1301 (0.512 sec)
# INFO:tensorflow:global_step/sec: 190.55
# INFO:tensorflow:loss = 37.74443, step = 1401 (0.525 sec)
# INFO:tensorflow:global_step/sec: 184.04
# INFO:tensorflow:loss = 44.627068, step = 1501 (0.543 sec)
# INFO:tensorflow:global_step/sec: 192.903
# INFO:tensorflow:loss = 50.548386, step = 1601 (0.518 sec)
# INFO:tensorflow:global_step/sec: 192.137
# INFO:tensorflow:loss = 25.732203, step = 1701 (0.520 sec)
# INFO:tensorflow:global_step/sec: 192.074
# INFO:tensorflow:loss = 30.196468, step = 1801 (0.521 sec)
# INFO:tensorflow:global_step/sec: 182.608
# INFO:tensorflow:loss = 35.89875, step = 1901 (0.548 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tmp5eueu48r/model.ckpt.
# INFO:tensorflow:Loss for final step: 33.481873.

# %% [markdown]
# ### What-If Tool analysis
#
# We can see the same unfairness that ProPublica found in their analysis by:
# 1. Going the the "Performance + Fairness" tab
# 2. Setting "Ground Truth Feature" to "recidivism_within_2_years"
# 3. Click "Optimize Threshold"
# 4. In "Slice by" dropdown menu, select "race"
# 5. Look at the confusion matrices of the "African-American" and "Causasian" slices.
#   - They have very similar accuracy (TP+FP)
#   - But, the FP rate is MUCH higher for African Americans and the FN rate is MUCH lower for caucasians

# %%
num_datapoints = 10000  #@param {type: "number"}
tool_height_in_px = 1000  #@param {type: "number"}

from witwidget.notebook.visualization import WitConfigBuilder
from witwidget.notebook.visualization import WitWidget

# Setup the tool with the test examples and the trained classifier
config_builder = WitConfigBuilder(examples[0:num_datapoints]).set_estimator_and_feature_spec(
    classifier, feature_spec)
WitWidget(config_builder, height=tool_height_in_px)
# Out:
# <style>.container { width:100% !important; }</style>
# WitWidget(config={'model_type': 'classification', 'label_vocab': [], 'inference_address': 'estimator', 'model_…
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
